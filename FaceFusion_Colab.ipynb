# %% [markdown]
# <a href="https://colab.research.google.com/github/yyyrrreeewwwqqqttt-sketch/faceforge-ai./blob/main/FaceFusion_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/facefusion/facefusion.git
# %cd /content/facefusion
# !pip install -r requirements.txt
# !pip install onnxruntime-gpu
# Out:
# Cloning into 'facefusion'...
# remote: Enumerating objects: 7674, done.
# remote: Total 7674 (delta 0), reused 0 (delta 0), pack-reused 7674 (from 1)
# Receiving objects: 100% (7674/7674), 30.02 MiB | 29.38 MiB/s, done.
# Resolving deltas: 100% (5431/5431), done.
# /content/facefusion
# Collecting gradio-rangeslider==0.0.8 (from -r requirements.txt (line 1))
#   Downloading gradio_rangeslider-0.0.8-py3-none-any.whl.metadata (10 kB)
# Collecting gradio==5.50.0 (from -r requirements.txt (line 2))
#   Downloading gradio-5.50.0-py3-none-any.whl.metadata (16 kB)
# Collecting numpy==2.4.6 (from -r requirements.txt (line 3))
#   Downloading numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting onnx==1.22.0 (from -r requirements.txt (line 4))
#   Downloading onnx-1.22.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Collecting onnxruntime==1.28.0 (from -r requirements.txt (line 5))
#   Downloading onnxruntime-1.28.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: opencv-python-headless==5.0.0.93 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (5.0.0.93)
# Collecting tqdm==4.70.0 (from -r requirements.txt (line 7))
#   Downloading tqdm-4.70.0-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 3.9 MB/s eta 0:00:00
# Collecting scipy==1.18.0 (from -r requirements.txt (line 8))
#   Downloading scipy-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 5.0 MB/s eta 0:00:00
# Collecting aiofiles<25.0,>=22.0 (from gradio==5.50.0->-r requirements.txt (line 2))
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.50.0->-r requirements.txt (line 2)) (4.14.2)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.50.0->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio==5.50.0->-r requirements.txt (line 2)) (0.141.1)
# Collecting ffmpy (from gradio==5.50.0->-r requirements.txt (line 2))
#   Downloading ffmpy-1.0.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.14.0 (from gradio==5.50.0->-r requirements.txt (line 2))
#   Downloading gradio_client-1.14.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio==5.50.0->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio==5.50.0->-r requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in /usr/local/lib/python3.12/dist-packages (from gradio==5.50.0->-r requirements.txt (line 2)) (1.27.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.50.0->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.50.0->-r requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.50.0->-r requirements.txt (line 2)) (3.12.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio==5.50.0->-r requirements.txt (line 2)) (26.3)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.50.0->-r requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.50.0->-r requirements.txt (line 2)) (11.3.0)
# Collecting pydantic<=2.12.3,>=2.0 (from gradio==5.50.0->-r requirements.txt (line 2))
#   Downloading pydantic-2.12.3-py3-none-any.whl.metadata (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.7/87.7 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio==5.50.0->-r requirements.txt (line 2)) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio==5.50.0->-r requirements.txt (line 2)) (0.0.32)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.50.0->-r requirements.txt (line 2)) (6.0.3)
# Collecting ruff>=0.9.3 (from gradio==5.50.0->-r requirements.txt (line 2))
#   Downloading ruff-0.16.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio==5.50.0->-r requirements.txt (line 2)) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.50.0->-r requirements.txt (line 2)) (2.10.0)
# Collecting starlette<1.0,>=0.40.0 (from gradio==5.50.0->-r requirements.txt (line 2))
#   Downloading starlette-0.52.1-py3-none-any.whl.metadata (6.3 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio==5.50.0->-r requirements.txt (line 2))
#   Downloading tomlkit-0.13.3-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio==5.50.0->-r requirements.txt (line 2)) (0.27.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.50.0->-r requirements.txt (line 2)) (4.16.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.50.0->-r requirements.txt (line 2)) (0.52.3)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx==1.22.0->-r requirements.txt (line 4)) (5.29.6)
# Requirement already satisfied: ml_dtypes>=0.5.4 in /usr/local/lib/python3.12/dist-packages (from onnx==1.22.0->-r requirements.txt (line 4)) (0.6.0)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime==1.28.0->-r requirements.txt (line 5)) (25.12.19)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio==5.50.0->-r requirements.txt (line 2)) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio==5.50.0->-r requirements.txt (line 2)) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio==5.50.0->-r requirements.txt (line 2)) (3.18)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio==5.50.0->-r requirements.txt (line 2)) (0.4.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio==5.50.0->-r requirements.txt (line 2)) (0.0.5)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio==5.50.0->-r requirements.txt (line 2)) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio==5.50.0->-r requirements.txt (line 2)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio==5.50.0->-r requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio==5.50.0->-r requirements.txt (line 2)) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio==5.50.0->-r requirements.txt (line 2)) (3.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio==5.50.0->-r requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==5.50.0->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==5.50.0->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==5.50.0->-r requirements.txt (line 2)) (2026.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.12.3,>=2.0->gradio==5.50.0->-r requirements.txt (line 2)) (0.8.0)
# Collecting pydantic-core==2.41.4 (from pydantic<=2.12.3,>=2.0->gradio==5.50.0->-r requirements.txt (line 2))
#   Downloading pydantic_core-2.41.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==5.50.0->-r requirements.txt (line 2)) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==5.50.0->-r requirements.txt (line 2)) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio==5.50.0->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio==5.50.0->-r requirements.txt (line 2)) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio==5.50.0->-r requirements.txt (line 2)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0,>=0.12->gradio==5.50.0->-r requirements.txt (line 2)) (0.1.2)
# Downloading gradio_rangeslider-0.0.8-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 38.8 MB/s eta 0:00:00
# Downloading gradio-5.50.0-py3-none-any.whl (63.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 MB 12.9 MB/s eta 0:00:00
# Downloading numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 83.8 MB/s eta 0:00:00
# Downloading onnx-1.22.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (19.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 65.5 MB/s eta 0:00:00
# Downloading onnxruntime-1.28.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (19.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 77.6 MB/s eta 0:00:00
# Downloading tqdm-4.70.0-py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 5.9 MB/s eta 0:00:00
# Downloading scipy-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 12.9 MB/s eta 0:00:00
# Downloading gradio_client-1.14.0-py3-none-any.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.6/325.6 kB 16.5 MB/s eta 0:00:00
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading pydantic-2.12.3-py3-none-any.whl (462 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.4/462.4 kB 9.5 MB/s eta 0:00:00
# Downloading pydantic_core-2.41.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 69.1 MB/s eta 0:00:00
# Downloading ruff-0.16.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 77.2 MB/s eta 0:00:00
# Downloading starlette-0.52.1-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 5.9 MB/s eta 0:00:00
# Downloading tomlkit-0.13.3-py3-none-any.whl (38 kB)
# Downloading ffmpy-1.0.0-py3-none-any.whl (5.6 kB)
# Installing collected packages: tqdm, tomlkit, ruff, pydantic-core, numpy, ffmpy, aiofiles, starlette, scipy, pydantic, onnxruntime, onnx, gradio-client, gradio, gradio-rangeslider
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.3
#     Uninstalling tqdm-4.67.3:
#       Successfully uninstalled tqdm-4.67.3
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.14.0
#     Uninstalling tomlkit-0.14.0:
#       Successfully uninstalled tomlkit-0.14.0
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.46.4
#     Uninstalling pydantic_core-2.46.4:
#       Successfully uninstalled pydantic_core-2.46.4
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: aiofiles
#     Found existing installation: aiofiles 25.1.0
#     Uninstalling aiofiles-25.1.0:
#       Successfully uninstalled aiofiles-25.1.0
#   Attempting uninstall: starlette
#     Found existing installation: starlette 1.6.0
#     Uninstalling starlette-1.6.0:
#       Successfully uninstalled starlette-1.6.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.13.4
#     Uninstalling pydantic-2.13.4:
#       Successfully uninstalled pydantic-2.13.4
#   Attempting uninstall: gradio-client
#     Found existing installation: gradio_client 2.6.0
#     Uninstalling gradio_client-2.6.0:
#       Successfully uninstalled gradio_client-2.6.0
#   Attempting uninstall: gradio
#     Found existing installation: gradio 6.24.0
#     Uninstalling gradio-6.24.0:
#       Successfully uninstalled gradio-6.24.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.4.6 which is incompatible.
# python-fasthtml 0.14.11 requires starlette>=1.0.1, but you have starlette 0.52.1 which is incompatible.
# hf-gradio 0.4.1 requires gradio-client<3.0,>=2.0, but you have gradio-client 1.14.0 which is incompatible.
# google-adk 2.7.0 requires starlette<2,>=1.3.1, but you have starlette 0.52.1 which is incompatible.
# google-genai 2.12.1 requires pydantic<3.0.0,>=2.12.5, but you have pydantic 2.12.3 which is incompatible.
# Successfully installed aiofiles-24.1.0 ffmpy-1.0.0 gradio-5.50.0 gradio-client-1.14.0 gradio-rangeslider-0.0.8 numpy-2.4.6 onnx-1.22.0 onnxruntime-1.28.0 pydantic-2.12.3 pydantic-core-2.41.4 ruff-0.16.3 scipy-1.18.0 starlette-0.52.1 tomlkit-0.13.3 tqdm-4.70.0
# Collecting onnxruntime-gpu
#   Downloading onnxruntime_gpu-1.29.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (5.9 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (25.12.19)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (2.4.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (26.3)
# Requirement already satisfied: protobuf>=4.25.8 in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu) (5.29.6)
# Downloading onnxruntime_gpu-1.29.0-cp312-cp312-manylinux_2_28_x86_64.whl (202.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.2/202.2 MB 5.9 MB/s eta 0:00:00
# Installing collected packages: onnxruntime-gpu
# Successfully installed onnxruntime-gpu-1.29.0

# %%
# Path to the core.py file
file_path = '/content/facefusion/facefusion/uis/layouts/default.py'

# Read the content of the file
with open(file_path, 'r') as file:
    content = file.read()

# Replace the line with the updated version
updated_content = content.replace("ui.launch(show_api = False)", "ui.launch(show_api = False, share=True, enable_queue=True)")

# Write the updated content back to the file
with open(file_path, 'w') as file:
    file.write(updated_content)

# %%
# !python run.py
